# %% [markdown]
# # Exploratory data analysis process
#
# In this notebook, I will analyze the data structure my Top Spotify Tracks from 2016 to 2022.The dataset contains 100 of my top songs each year .

# %%
#Import libraries
import pandas as pd
import numpy as np
from tqdm import tqdm

# Data Visualization
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import re
from wordcloud import WordCloud

# Import the library
import plotly.express as px

# %% [markdown]
# ## Load data

# %%
songs = pd.read_csv('../data/my_top_songs.csv')
songs.head()
# Out:
#    Unnamed: 0        artist_name  artist_pop  \
# 0           0        Alan Walker          82
# 1           1  Twenty One Pilots          81
# 2           2      New Beat Fund          41
# 3           3    The Strumbellas          58
# 4           4               Kygo          81
#
#                                        artist_genres               track_name  \
# 0                                  ['electro house']                    Faded
# 1                            ['modern rock', 'rock']                     Ride
# 2                                                 []                  No Type
# 3  ['canadian indie', 'folk-pop', 'pop rock', 'st...                  Spirits
# 4      ['edm', 'pop', 'pop dance', 'tropical house']  Raging (feat. Kodaline)
#
#                  track_id               track_uri  popularity  danceability  \
# 0  1brwdYwjltrJo7WHpIvbYt  1brwdYwjltrJo7WHpIvbYt           0         0.589
# 1  2Z8WuEywRWYTKe1NybPQEW  2Z8WuEywRWYTKe1NybPQEW          83         0.645
# 2  4fxtYgcIOqjCq9Ix1pvrzn  4fxtYgcIOqjCq9Ix1pvrzn          47         0.619
# 3  1mqbTByfUxLPeqN1YEw08a  1mqbTByfUxLPeqN1YEw08a           0         0.553
# 4  6DsFZITJMPnh8z5XewfVmL  6DsFZITJMPnh8z5XewfVmL          61         0.550
#
#    energy  ...  valence    tempo            type                      id  \
# 0   0.651  ...    0.166   90.011  audio_features  1brwdYwjltrJo7WHpIvbYt
# 1   0.713  ...    0.566   74.989  audio_features  2Z8WuEywRWYTKe1NybPQEW
# 2   0.622  ...    0.210  136.978  audio_features  4fxtYgcIOqjCq9Ix1pvrzn
# 3   0.724  ...    0.775   80.517  audio_features  1mqbTByfUxLPeqN1YEw08a
# 4   0.689  ...    0.408   99.904  audio_features  6DsFZITJMPnh8z5XewfVmL
#
#                                     uri  \
# 0  spotify:track:1brwdYwjltrJo7WHpIvbYt
# 1  spotify:track:2Z8WuEywRWYTKe1NybPQEW
# 2  spotify:track:4fxtYgcIOqjCq9Ix1pvrzn
# 3  spotify:track:1mqbTByfUxLPeqN1YEw08a
# 4  spotify:track:6DsFZITJMPnh8z5XewfVmL
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1brwdYwjltrJ...
# 1  https://api.spotify.com/v1/tracks/2Z8WuEywRWYT...
# 2  https://api.spotify.com/v1/tracks/4fxtYgcIOqjC...
# 3  https://api.spotify.com/v1/tracks/1mqbTByfUxLP...
# 4  https://api.spotify.com/v1/tracks/6DsFZITJMPnh...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1brw...       212627
# 1  https://api.spotify.com/v1/audio-analysis/2Z8W...       214507
# 2  https://api.spotify.com/v1/audio-analysis/4fxt...       213797
# 3  https://api.spotify.com/v1/audio-analysis/1mqb...       203653
# 4  https://api.spotify.com/v1/audio-analysis/6DsF...       224487
#
#    time_signature  year
# 0               4  2016
# 1               4  2016
# 2               4  2016
# 3               4  2016
# 4               4  2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Data Preparation
# First we need to prepare our dataframe. We're going to drop columns `track_id`, `track_uri`, `type`, `id`, `uri`,`track_href` and `analysis_url` as we don't need them for this application. Then we convert the song duration from millieseconds to seconds

# %%
#Drop columns
columns_to_drop=['track_id', 'track_uri', 'type', 'id', 'uri','track_href','analysis_url']
songs=songs.drop(columns_to_drop,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [4], line 2
#       1 # Drop columns
# ----> 2 songs.drop(['track_id', 'track_uri', 'type', 'id', 'uri','track_href','analysis_url'])
#       3 # Convert duration from ms to sec
#       4 songs['duration_ms']=songs['duration_ms']*10**-3
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:5388, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5240 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5241 def drop(  # type: ignore[override]
#    5242     self,
#    (...)
#    5249     errors: IgnoreRaise = "raise",
#    5250 ) -> DataFrame | None:
#    5251     """
#    5252     Drop specified labels from rows or columns.
#    5253
#    (...)
#    5386             weight  1.0     0.8
#    5387     """
# -> 5388     return super().drop(
#    5389         labels=labels,
#    5390         axis=axis,
#    5391         index=index,
#    5392         columns=columns,
#    5393         level=level,
#    5394         inplace=inplace,
#    5395         errors=errors,
#    5396     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6975, in Index.drop(self, labels, errors)
#    6973 if mask.any():
#    6974     if errors != "ignore":
# -> 6975         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6976     indexer = indexer[~mask]
#    6977 return self.delete(indexer)
#
# KeyError: "['track_id', 'track_uri', 'type', 'id', 'uri', 'track_href', 'analysis_url'] not found in axis"

# %% [markdown]
# ## Data Visualisation
# First we're going to visualise what are the most common genres the artist I listened more over the years are associated with, by creating a wordcloud based on music genre

# %%
top_gernes = ' '.join([word for word in songs['artist_genres']])
wordcloud_gernes = WordCloud(width=600,
                             height=400,
                             random_state=2,
                             max_font_size=100,
                             colormap='magma',
                             background_color="white").generate(top_gernes)


# Create a figure object and set its size and title
fig = plt.figure(figsize=(12, 6))
# showing image
plt.imshow(wordcloud_gernes)
plt.axis('off')
plt.title("Favorite artist gernes")

# %% [markdown]
# Now that we have the data, let’s take a look at the features for each song. For this subpart specifically, we will be looking at the mean values of the features for the top 100 most popular songs, as well as all of the dataset. To visualize this we can use a radar chart as below. The code below is:
#
# Obtaining all of the labels of the data, in our case the audio features, and taking their means. There are two variables: “features”, with the average values of the audio features for the top 100 songs and “features_all”, with the means for all of the dataset.
# Plotting the “features” and “features_all” on the same radar plot with different colors.

# %%
features= ['danceability','liveness','energy','valence','speechiness','acousticness','year']
song_feat=songs.loc[:,features]

summary_stats = song_feat.groupby(["year"]).mean().reset_index()

# %%
# Create the chart:
fig = px.parallel_coordinates(
    summary_stats,
    dimensions=['danceability','liveness','energy','valence','speechiness','acousticness'],
    color="year",
    color_continuous_scale=px.colors.diverging.Tealrose,
    color_continuous_midpoint=0.5,
    title = 'PCP High Quality Wines  Without Reordering')

# Hide the color scale that is useless in this case
fig.update_layout(coloraxis_showscale=False)

# Show the plot
fig.show()
